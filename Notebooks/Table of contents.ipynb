# %% [markdown]
# # Table of Contents

# %% [markdown]
# #### REDCap Overview
# Definitions<br>
# REDCap Data Building Blocks<br>
#
# #### Exporting with REDCapR
# Records <br>
#     - Understanding data structure (repeat in both pycap and redcapr)
#
# Reports <br>
#
# Files: Optional Attachments to Individual Records <br>
#
# Metadata (generic) <br>
#
# Field Names <br>
#
# Events/Instruments <br>
#     - Instruments <br>
#     - Instrument Event Map <br>
#     - Repeating Instruments and Events (add this in?) <br>
#
# Survey Settings and Other Information <br>
#     - Users and User Roles <br>
#     - Data Access Groups (DAGs) <br>
#     - Logging <br>
#     - Survey Link <br>
#     - REDCap Version <br>
#
# Advanced Knowledge <br>
#     - Example: REDCap Projects and Data Structures <br>
#     - Native API Examples <br>
#     - Indexing <br>
#     - Filtering Data using REDCapR Functions <br>
#     - Filtering Data using R <br>
#     - Other Functions for Exporting REDCap Records <br>
#     - Metadata (generic) <br>
#     - REDCap Constants <br>
#
# #### Importing with REDCapR
# Records <br>
#
# Files: Optional Attachments to Individual Records <br>
#
# Metadata (generic) <br>
#
# Data Validation <br>
#
# Cannot be Imported with REDCapR - NOTE (can move to appendix?) <br>
#     - Field Names, Forms/Instruments, Instrument Event Map, Reports, Logging, Users and User Roles, Data Access Groups (DAGs) <br>
#     - Can be imported in REDCap but not REDCapR: [ADD HERE] <br>
#
# Advanced Knowledge<br>
#     - Example: REDCap Projects and Data Structures <br>
#     - Example: Uploading Records from a CSV <br>
#
# #### Exporting with Pycap
# Records <br>
#     - Understanding data structure (repeat in both pycap and redcapr)
#
# Reports <br>
#
# Files: Optional Attachments to Individual Records <br>
#
# Metadata (generic) <br>
#
# Field Names <br>
#
# Events/Instruments <br>
#     - Instruments <br>
#     - Instrument Event Map <br>
#     - Repeating Instruments and Events (add this in?) <br>
#
# Survey Settings and Other Information <br>
#     - Users and User Roles <br>
#     - Data Access Groups (DAGs) <br>
#     - Logging <br>
#     - Survey Link (currently nothing for this section?) <br>
#     - REDCap Version (currently nothing for this section?) <br>
#
# Advanced Knowledge <br>
#     - Example: REDCap Projects and Data Structures <br>
#     - Native API Examples <br>
#     - Indexing <br>
#     - Filtering Data using REDCapR Functions <br>
#     - Filtering Data using R <br>
#     - Other Functions for Exporting REDCap Records <br>
#     - Metadata (generic) <br>
#     - REDCap Constants <br>
#
# #### Importing with Pycap
# Records <br>
#
# Files: Optional Attachments to Individual Records <br>
#
# Metadata (generic) <br>
#
# Data Validation (currently nothing for this section?) <br>
#
# Cannot be Imported with PyCap - NOTE (can move to appendix?) <br>
#     - Field Names, Forms/Instruments, Instrument Event Map, Reports, Logging, Users and User Roles, Data Access Groups (DAGs) <br>
#     - Can be imported in REDCap but not PyCap: [ADD HERE] <br>
#
# Advanced Knowledge <br>
#     - Example: Uploading Records from a CSV <br>
#     - Import Using Native API <br>
#
# #### Advanced REDCap API Import Behavior
# Validations required for API import into REDcap <br>
# Validation not required for API import into REDcap <br>
# Unexpected Behavior in API Import <br>
#
# #### Native API
# Take out all native API instructions and put them in their own section?
